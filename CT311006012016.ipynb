# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav-Lejith/Practicals/blob/main/CT311006012016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SET- 1**

# %%
# Q1
import numpy as np
f=np.full((2,2),5)
print(f)
z=np.zeros((2,2),dtype=int)
print(z)
o=np.ones((2,2),dtype=int)
print(o)
# Out:
# [[5 5]
#  [5 5]]
# [[0 0]
#  [0 0]]
# [[1 1]
#  [1 1]]

# %% [markdown]
# OR

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('student.csv')
print(df.head(5))
# Out:
#    rno name  english  ai  marks
# 0    1  aaa       41  55     96
# 1    2  bbb       45  43     88
# 2    3  ccc       45  49     94
# 3    4  ddd       54  90    144
# 4    5  eee       83  44    127

# %%
# Q2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=np.array([2,9,8,5,6])
y=np.array([5,10,3,7,18])
plt.scatter(x,y)
plt.show()

# %%
# Q3
import cv2
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread('w11.jpg',0)
plt.imshow(img, cmap='gray')
plt.title('Gray Image')
plt.axis('on')
# Out:
# (np.float64(-0.5), np.float64(8191.5), np.float64(5461.5), np.float64(-0.5))

# %% [markdown]
# # **SET-2**

# %%
# Q1
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
min1=a.min(axis=0)
min2=a.min(axis=1)
max1=a.max(axis=0)
max2=a.max(axis=1)
print(min1)
print(min2)
print(max1)
print(max2)
# Out:
# [1 2 3]
# [1 4]
# [4 5 6]
# [3 6]

# %% [markdown]
# OR

# %%
import pandas as pd
df=pd.read_csv('student.csv')
print(df.tail(5))
# Out:
#    rno name  english  ai  marks
# 5    6  fff       93  72    165
# 6    7  ggg       66  59    125
# 7    8  hhh       75  64    139
# 8    9  iii       71  77    148
# 9   10  jjj       54  66    120

# %%
# Q2
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,9])
y=np.array([5,10])
plt.plot(x,y)
plt.show()

# %%
# Q3
# PROGRAM 3 - Cropping
import cv2
import matplotlib.pyplot as plt
import numpy as np
img5=cv2.imread('w11.jpg')
roi = img5[0:4000, 200:5000]
plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
plt.title('Extracted Image')
plt.axis('off')
#plt.show()
# Out:
# (np.float64(-0.5), np.float64(4799.5), np.float64(3999.5), np.float64(-0.5))

# %% [markdown]
# # **SET-3**

# %%
# Q1
import numpy as np
a=np.array([10,20,30,40,50])
b=np.array([50,40,30,20,10])
c=input('Enter choice: ')
match c:
  case '+':
    print(a+b)
  case '-':
    print(a-b)
  case '*':
    print(a*b)
  case '/':
    print(a/b)
  case _:
    print('Enter valid operator')
# Out:
# Enter choice: 1
# Enter valid operator

# %% [markdown]
# OR

# %%
import pandas as pd
df=pd.read_csv('student.csv')
print(df.loc[1:5])
# Out:
#    rno name  english  ai  marks
# 1    2  bbb       45  43     88
# 2    3  ccc       45  49     94
# 3    4  ddd       54  90    144
# 4    5  eee       83  44    127
# 5    6  fff       93  72    165

# %%
# Q2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('student.csv')
plt.xlabel('Name')
plt.ylabel('Marks')
x=df.name
y=df.marks
plt.title('Performance')
plt.bar(x,y,width=0.5,align='edge')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt


img = cv2.imread('w11.jpg', cv2.IMREAD_GRAYSCALE)


crop = img[1800:3000, 2500:4300]


img[0:1200, 0:1800] = crop
img[3800:5000, 0:1800] = crop


plt.imshow(img, cmap='gray')
plt.title('Replicated Car Part')
plt.axis('off')
plt.show()

# %% [markdown]
# # **SET - 4**

# %%
# Q1
import numpy as np
from scipy import stats as st
a=np.array([10,20,30,40,10,40,10,50])
print(f'Mean = {np.mean(a)} \n Median = {np.median(a)} \n Mode = {st.mode(a)}')
# Out:
# Mean = 26.25
#  Median = 25.0
#  Mode = ModeResult(mode=np.int64(10), count=np.int64(3))

# %% [markdown]
# OR

# %%
import pandas as pd
df=pd.read_csv('student.csv')
print(df[['name','marks']])
# Out:
#   name  marks
# 0  aaa     96
# 1  bbb     88
# 2  ccc     94
# 3  ddd    144
# 4  eee    127
# 5  fff    165
# 6  ggg    125
# 7  hhh    139
# 8  iii    148
# 9  jjj    120

# %%
# Q2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('JaipurFinalCleanData.csv')
plt.xlabel('Min Temp')
plt.ylabel('Frequency')
y=df.meantempm
plt.title('Min Temp')
plt.hist(x,bins=10)
plt.show()

# %%
# Q3
# WAP to blackout a man's face (need to change coordinates according to textbook page)

# Page 280: Blackout man's face (here car)

import cv2
from matplotlib import pyplot as plt
import numpy as np

img5=cv2.imread('w11.jpg')
img5[0:4000, 200:5000] = [0,0,0]  # Change the pixel values in the specified region to black
plt.imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))
plt.title('Blacked Out image')
plt.axis('on')
plt.show()

# %% [markdown]
# # **SET-5**

# %%
# Q1
import numpy as np
a=np.array([[50,40,10,20],[60,20,5,25]])
print(f'Row Wise Sorting \n {np.sort(a,axis=0)}')
print(f'Column Wise Sorting \n {np.sort(a,axis=1)}')
# Out:
# Row Wise Sorting
#  [[50 20  5 20]
#  [60 40 10 25]]
# Column Wise Sorting
#  [[10 20 40 50]
#  [ 5 20 25 60]]

# %% [markdown]
# Or

# %%
import pandas as pd
df=pd.read_csv('student.csv')
print(df.sort_values('name',axis=0))
# Out:
#    rno name  english  ai  marks
# 0    1  aaa       41  55     96
# 1    2  bbb       45  43     88
# 2    3  ccc       45  49     94
# 3    4  ddd       54  90    144
# 4    5  eee       83  44    127
# 5    6  fff       93  72    165
# 6    7  ggg       66  59    125
# 7    8  hhh       75  64    139
# 8    9  iii       71  77    148
# 9   10  jjj       54  66    120

# %%
# Q2
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('student.csv')
x=df.ai
plt.boxplot(x)
plt.show()

# %%
# Q3
# PROGRAM 3 - Cropping
import cv2
import matplotlib.pyplot as plt
import numpy as np
img5=cv2.imread('w11.jpg')
roi = img5[0:4000, 200:5000]
plt.imshow(cv2.cvtColor(roi, cv2.COLOR_BGR2RGB))
plt.title('Extracted Image')
plt.axis('off')
plt.show()

# %% [markdown]
# # **SET - 6**

# %%
# Q1
import numpy as np
print(np.random.randint(30,size=(3,3)))
# Out:
# [[16 19  4]
#  [15 20  2]
#  [ 5  1 25]]

# %% [markdown]
# Or

# %%
import pandas as pd
df=pd.read_csv('student.csv')
print(df.drop([5],axis=0))
# Out:
#    rno name  english  ai  marks
# 0    1  aaa       41  55     96
# 1    2  bbb       45  43     88
# 2    3  ccc       45  49     94
# 3    4  ddd       54  90    144
# 4    5  eee       83  44    127
# 6    7  ggg       66  59    125
# 7    8  hhh       75  64    139
# 8    9  iii       71  77    148
# 9   10  jjj       54  66    120

# %%
# Q2
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=np.array([2,9,8,5,6])
y=np.array([5,10,3,7,18])
plt.scatter(x,y)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('w11.jpg',0)
plt.imshow(img, cmap='gray')
plt.title('Gray Image')
plt.axis('on')
# Out:
# (np.float64(-0.5), np.float64(8191.5), np.float64(5461.5), np.float64(-0.5))

# %% [markdown]
# # **Experimental test Programs(NOT INCLUDED):**

# %%
import matplotlib.pyplot as plt

data = [12, 15, 12, 18, 20, 22, 25, 25, 25, 30, 35, 38, 40, 45, 50]

plt.hist(data, bins=5, color='skyblue', edgecolor='black')

plt.xlabel('Value Ranges')
plt.ylabel('Frequency')
plt.title('Histogram with Custom Data')

plt.show()
